# %%
import sys
sys.path.append('../core/')
sys.path.append('../networks/')
from cdraw import DRAW
from networks import *

import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/jucheng/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
tf.reset_default_graph()

# %%
sess = tf.InteractiveSession()
build_encoder = Encoder(256)
build_decoder = Decoder(256)
train_iters = 0
print_iters = 100

# %%
model =  DRAW(sess, build_encoder, build_decoder, read_attn = True, write_attn = True)

# %%
model.train(train_itrs = train_iters, learning_rate = 1e-4, load = True, save = False)
# Out:
# Extracting mnist/train-images-idx3-ubyte.gz
# Extracting mnist/train-labels-idx1-ubyte.gz
# Extracting mnist/t10k-images-idx3-ubyte.gz
# Extracting mnist/t10k-labels-idx1-ubyte.gz

# %%
plt.plot(range(train_iters), model.Lxs, range(train_iters), model.Lzs)
# Out:
# [<matplotlib.lines.Line2D at 0x136418cd0>,
#  <matplotlib.lines.Line2D at 0x136418ed0>]

# %%
generated_images = model.generate()

# %%
generated_images.shape
# Out:
# (10, 100, 784)

# %%
T = 10
num_examples = 10

plt.figure(figsize=(20,20))
for t in xrange(10):
    for n in xrange(num_examples):
        plt.subplot(num_examples, T, T* n + t + 1)
        plt.imshow(generated_images[t,n, ].reshape(28, 28), cmap='gray_r')
        plt.xticks([])
        plt.yticks([])
plt.tight_layout()
plt.show()
